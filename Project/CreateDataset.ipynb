# %%
import pandas as pd
import numpy as np
import random

def create_dataset(hm, min_gpa=5, max_gpa=10):
    f = open('dataset.txt','w')
    f.write("ten_gpa,twelth_gpa,colz_gpa,nimcet_marks,psqt_gpa,me_gpa,co_gpa,pscp_gpa,pscp_lab_gpa,foss_lab_gpa,sgpa1,afm_gpa,ds_gpa,ss_gpa,oops_gpa,aad_gpa,ds_lab_gpa,ss_lab_gpa,oops_lab_gpa,sgpa2,cgpa2,os_gpa,dbms_gpa,wt_gpa,ospm_gpa,ads_gpa,os_lab_gpa,dbms_lab_gpa,wt_lab_gpa,sgpa3,cgpa3,pdwdm_gpa,ccn_gpa,se_gpa,ooad_gpa,dos_gpa,ke_lab_gpa,ccn_lab_gpa,set_lab_gpa,sgpa4,cgpa4,nps_gpa,uc_gpa,cc_gpa,dpsa_gpa,stt_gpa,seminar_viva_gpa,nps_lab_gpa,stt_lab_gpa,sgpa5,cgpa5,project_gpa,cgpa_final")
    f.write("\n")
    while hm > 0:
        ten_gpa =  round(random.uniform(min_gpa,max_gpa), 2)
        twelth_gpa = 0.0
        if ten_gpa >= 8.0:
            min_gpa = 7
        else:
            max_gpa = 8.0
        
        rand = random.randint(1, 10)
        if rand == 1:
                min_gpa = 5
        
        twelth_gpa = round(random.uniform(min_gpa,max_gpa), 2)
        if twelth_gpa >=8.0 and ten_gpa >= 8:
            min_gpa = 8
            max_gpa = 10
            rand = random.randint(1, 10)
            if rand == 1:
                min_gpa = 5
        elif twelth_gpa >= 8.0:
            min_gpa = 7
            max_gpa = 9
            rand = random.randint(1, 10)
            if rand <= 2:
                min_gpa = 5
        else:
            min_gpa = 5
            max_gpa = 8
           
        colz_gpa = round(random.uniform(min_gpa, max_gpa), 2)
        min_marks = 390
        if twelth_gpa >=8.0 and colz_gpa >=8.0:
            min_marks = 650
            max_marks = 950
            rand = random.randint(1, 10)
            if rand == 1:
                min_marks = 450
        elif colz_gpa >=8.0:
            min_marks = 550
            max_marks = 700
            rand = random.randint(1, 10)
            if rand <= 2:
                min_marks = 400
        else:
            max_marks = 650
        
        nimcet_marks= round(random.uniform(min_marks, max_marks), 2)
        if colz_gpa >= 8 and nimcet_marks >=750:
            min_gpa = 8
            max_gpa = 10
            rand = random.randint(1, 10)
            if rand == 1:
                min_gpa = 5
        elif colz_gpa >= 7 and nimcet_marks >=500:
            min_gpa = 6
            max_gpa = 9
            rand = random.randint(1, 10)
            if rand <= 2:
                min_gpa = 5
        else:
            min_gpa = 5
            max_gpa = 8
        #random_gpa = round(random.uniform(min_gpa,max_gpa), 2)
        
        psqt_gpa = random.randint(min_gpa, max_gpa)
        me_gpa = random.randint(min_gpa, max_gpa)
        mlcgt_gpa = random.randint(min_gpa, max_gpa)
        co_gpa = random.randint(min_gpa, max_gpa)
        pscp_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (pscp_gpa - 1) if (pscp_gpa - 1) >= 5 else 5
        max_gpa = (pscp_gpa + 2) if (pscp_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        pscp_lab_gpa = random.randint(min_gpa, max_gpa)
        foss_lab_gpa = random.randint(min_gpa, max_gpa)
       
        sgpa1 = (psqt_gpa + me_gpa + mlcgt_gpa + co_gpa + pscp_gpa + pscp_lab_gpa + foss_lab_gpa)/7.0
        
        if(me_gpa >=8 and sgpa1 >=8):
            min_gpa = 8
            max_gpa = 10
            rand = random.randint(1, 10)
            if rand == 1:
                min_gpa = 5
        
        elif(me_gpa >=6 and sgpa1 >=7):
            min_gpa = 6
            max_gpa = 9
            rand = random.randint(1, 10)
            if rand <= 2:
                min_gpa = 5
        
        else:
            min_gpa = 5
            max_gpa = 8
        
        afm_gpa = random.randint(min_gpa, max_gpa)
        if(pscp_gpa >=8 and pscp_lab_gpa >=8 and sgpa1 >=8):
            min_gpa = 8
            max_gpa = 10
            rand = random.randint(1, 10)
            if rand == 1:
                min_gpa = 5
        elif(pscp_gpa >=6 and sgpa1 >=7):
            min_gpa = 6
            max_gpa = 9
            rand = random.randint(1, 10)
            if rand <= 2:
                min_gpa = 5
        else:
            min_gpa = 5
            max_gpa = 8
        
        ds_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (pscp_gpa - 1) if (pscp_gpa - 1) >= 5 else 5
        max_gpa = (pscp_gpa + 2) if (pscp_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        ss_gpa = random.randint(min_gpa, max_gpa)
        oops_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (mlcgt_gpa - 1) if (mlcgt_gpa - 1) >= 5 else 5
        max_gpa = (mlcgt_gpa + 2) if (mlcgt_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        aad_gpa = random.randint(min_gpa, max_gpa)    
        min_gpa = (ds_gpa - 1) if (ds_gpa - 1) >= 5 else 5
        max_gpa = (ds_gpa + 2) if (ds_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        ds_lab_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (ss_gpa - 1) if (ss_gpa - 1) >= 5 else 5
        max_gpa = (ss_gpa + 2) if (ss_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
                
        ss_lab_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (oops_gpa - 1) if (oops_gpa - 1) >= 5 else 5
        max_gpa = (oops_gpa + 2) if (oops_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        oops_lab_gpa = random.randint(min_gpa, max_gpa)
        
        sgpa2 = round((afm_gpa+ds_gpa+ss_gpa+oops_gpa+aad_gpa+ds_lab_gpa+ss_lab_gpa+oops_lab_gpa)/8.0, 2)
        cgpa2 = round((sgpa2 + sgpa1)/2.0, 2)
        
        min_gpa = (co_gpa - 1) if (co_gpa - 1) >= 5 else 5
        max_gpa = (co_gpa + 2) if (co_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        os_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        max_gpa = (max_gpa + 1) if (max_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        dbms_gpa = random.randint(min_gpa, max_gpa)
        max_gpa = (max_gpa + 1) if (max_gpa + 1) <= 10 else 10
        wt_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (me_gpa - 1) if (me_gpa - 1) >= 5 else 5
        max_gpa = (me_gpa + 2) if (me_gpa + 2) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        ospm_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (ds_gpa - 1) if (ds_gpa - 1) >= 5 else 5
        max_gpa = (ds_gpa + 1) if (ds_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        ads_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (os_gpa - 1) if (os_gpa - 1) >= 5 else 5
        max_gpa = (os_gpa + 1) if (os_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        os_lab_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (dbms_gpa - 1) if (dbms_gpa - 1) >= 5 else 5
        max_gpa = (dbms_gpa + 1) if (dbms_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        dbms_lab_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (wt_gpa - 1) if (wt_gpa - 1) >= 5 else 5
        max_gpa = (wt_gpa + 1) if (wt_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        
        wt_lab_gpa = random.randint(min_gpa, max_gpa)
        
        sgpa3 = round((os_gpa + dbms_gpa + wt_gpa + ospm_gpa + ads_gpa + os_lab_gpa + dbms_lab_gpa + wt_lab_gpa)/8.0, 2)
        cgpa3 = round((sgpa1 + sgpa2 + sgpa3)/3.0 , 2)
        
        min_gpa = (dbms_gpa - 1) if (dbms_gpa - 1) >= 5 else 5
        max_gpa = (dbms_gpa + 1) if (dbms_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        pdwdm_gpa = random.randint(min_gpa, max_gpa)
        if cgpa3 >= 8:
            min_gpa = 8
            max_gpa = 10
            rand = random.randint(1, 10)
            if rand == 1:
                min_gpa = 5
        elif cgpa3 >= 6:
            min_gpa = 6
            max_gpa = 8
            rand = random.randint(1, 10)
            if rand <= 2:
                min_gpa = 5
        else:
            min_gpa = 5
            max_gpa = 7
        
        ccn_gpa = random.randint(min_gpa, max_gpa)
        sep_gpa = random.randint(min_gpa, max_gpa)
        ooad_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (os_gpa - 1) if (os_gpa - 1) >= 5 else 5
        max_gpa = (os_gpa + 1) if (os_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        dos_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (pdwdm_gpa - 1) if (pdwdm_gpa - 1) >= 5 else 5
        max_gpa = (pdwdm_gpa + 1) if (pdwdm_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        ke_lab_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (ccn_gpa - 1) if (ccn_gpa - 1) >= 5 else 5
        max_gpa = (ccn_gpa + 1) if (ccn_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        ccn_lab_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (sep_gpa - 1) if (sep_gpa - 1) >= 5 else 5
        max_gpa = (sep_gpa + 1) if (sep_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        set_lab_gpa = random.randint(min_gpa, max_gpa)
        
        sgpa4 = round((pdwdm_gpa + ccn_gpa + sep_gpa + ooad_gpa + dos_gpa + ke_lab_gpa + ccn_lab_gpa + set_lab_gpa)/8.0, 2)
        cgpa4 = round((sgpa1 + sgpa2 + sgpa3 + sgpa4)/ 4.0, 2)
        
        
        min_gpa = (ccn_gpa - 1) if (ccn_gpa - 1) >= 5 else 5
        max_gpa = (ccn_gpa + 1) if (ccn_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        nps_gpa = random.randint(min_gpa, max_gpa)
        if cgpa4 >= 8:
            min_gpa = 8
            max_gpa = 10
            rand = random.randint(1, 10)
            if rand == 1:
                min_gpa = 5
        elif cgpa4 >= 6:
            min_gpa = 6
            max_gpa = 8
            rand = random.randint(1, 10)
            if rand <= 2:
                min_gpa = 5
        else:
            min_gpa = 5
            max_gpa = 7
        
        
        
        uc_gpa = random.randint(min_gpa, max_gpa)
        cc_gpa = random.randint(min_gpa, max_gpa)
        seminar_viva_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (ooad_gpa - 1) if (ooad_gpa - 1) >= 5 else 5
        max_gpa = (ooad_gpa + 1) if (ooad_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        dpsa_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (sep_gpa - 1) if (sep_gpa - 1) >= 5 else 5
        max_gpa = (sep_gpa + 1) if (sep_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        stt_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (nps_gpa - 1) if (nps_gpa - 1) >= 5 else 5
        max_gpa = (nps_gpa + 1) if (nps_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        nps_lab_gpa = random.randint(min_gpa, max_gpa)
        min_gpa = (stt_gpa - 1) if (stt_gpa - 1) >= 5 else 5
        max_gpa = (stt_gpa + 1) if (stt_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        stt_lab_gpa = random.randint(min_gpa, max_gpa)
        
        
        sgpa5 = round((nps_gpa + uc_gpa + cc_gpa + dpsa_gpa + stt_gpa + seminar_viva_gpa + nps_lab_gpa + stt_lab_gpa)/8.0, 2)
        cgpa5 = round((sgpa1 + sgpa2 + sgpa3 + sgpa4 + sgpa5)/5.0, 2)
        
        min_gpa = (stt_gpa - 1) if (stt_gpa - 1) >= 5 else 5
        max_gpa = (stt_gpa + 1) if (stt_gpa + 1) <= 10 else 10
        
        rand = random.randint(1, 10)
        if rand <= 2:
                min_gpa = (min_gpa - 1) if (min_gpa - 1) >= 5 else 5
        
        project_gpa = random.randint(min_gpa, max_gpa)
          
        cgpa_final = round((sgpa1 + sgpa2 + sgpa3 + sgpa4 + sgpa5 + project_gpa)/6.0, 2)
        
        #print("%s \t %s \t   %s     %s \t   %s \t  %s \t %s \t %s \t %s \t\t %s  \t   %s\t %s \t %s \t   %s     %s \t   %s \t  %s \t %s \t %s \t %s \t\t %s %s \t %s \t   %s     %s \t   %s \t  %s \t %s \t %s \t %s \t\t %s %s \t %s \t   %s     %s \t   %s \t  %s \t %s \t %s \t %s \t\t %s  %s \t %s \t   %s     %s \t   %s \t  %s \t %s \t %s \t %s \t\t %s %s\t%s" % (ten_gpa, twelth_gpa, colz_gpa, nimcet_marks, psqt_gpa, me_gpa, co_gpa, pscp_gpa, pscp_lab_gpa, foss_lab_gpa, round(sgpa1, 2), afm_gpa, ds_gpa, ss_gpa, oops_gpa, aad_gpa, ds_lab_gpa, ss_lab_gpa, oops_lab_gpa, sgpa2, cgpa2, os_gpa, dbms_gpa, wt_gpa, ospm_gpa, ads_gpa, os_lab_gpa, dbms_lab_gpa, wt_lab_gpa, sgpa3, cgpa3, pdwdm_gpa, ccn_gpa, sep_gpa, ooad_gpa, dos_gpa, ke_lab_gpa, ccn_lab_gpa, set_lab_gpa, sgpa4, cgpa4, nps_gpa, uc_gpa, cc_gpa, dpsa_gpa, stt_gpa, seminar_viva_gpa, nps_lab_gpa, stt_lab_gpa, sgpa5, cgpa5, project_gpa, cgpa_final))
        #print(ten_gpa, twelth_gpa, colz_gpa, nimcet_marks, psqt_gpa, me_gpa, co_gpa, pscp_gpa, pscp_lab_gpa, foss_lab_gpa, round(sgpa1, 2), afm_gpa, ds_gpa, ss_gpa, oops_gpa, aad_gpa, ds_lab_gpa, ss_lab_gpa, oops_lab_gpa, sgpa2, cgpa2, os_gpa, dbms_gpa, wt_gpa, ospm_gpa, ads_gpa, os_lab_gpa, dbms_lab_gpa, wt_lab_gpa, sgpa3, cgpa3, pdwdm_gpa, ccn_gpa, sep_gpa, ooad_gpa, dos_gpa, ke_lab_gpa, ccn_lab_gpa, set_lab_gpa, sgpa4, cgpa4, nps_gpa, uc_gpa, cc_gpa, dpsa_gpa, stt_gpa, seminar_viva_gpa, nps_lab_gpa, stt_lab_gpa, sgpa5, cgpa5, project_gpa, cgpa_final)

        f.write("%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s\n" % (ten_gpa, twelth_gpa, colz_gpa, nimcet_marks, psqt_gpa, me_gpa, co_gpa, pscp_gpa, pscp_lab_gpa, foss_lab_gpa, round(sgpa1, 2), afm_gpa, ds_gpa, ss_gpa, oops_gpa, aad_gpa, ds_lab_gpa, ss_lab_gpa, oops_lab_gpa, sgpa2, cgpa2, os_gpa, dbms_gpa, wt_gpa, ospm_gpa, ads_gpa, os_lab_gpa, dbms_lab_gpa, wt_lab_gpa, sgpa3, cgpa3, pdwdm_gpa, ccn_gpa, sep_gpa, ooad_gpa, dos_gpa, ke_lab_gpa, ccn_lab_gpa, set_lab_gpa, sgpa4, cgpa4, nps_gpa, uc_gpa, cc_gpa, dpsa_gpa, stt_gpa, seminar_viva_gpa, nps_lab_gpa, stt_lab_gpa, sgpa5, cgpa5, project_gpa, cgpa_final))
        hm -= 1
    f.close()

create_dataset(100, 5, 10)
